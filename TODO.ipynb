# %% [markdown]
# # DuckieRace – TODO

# %% [markdown]
# ## 1. Kreuzung
#
# ### 1.1 Apriltagständer wird als gelb erkannt
# - [ ] Herausfinden welcher HSV-Bereich den Ständer fälschlicherweise als gelbe Linie erkennt
# - [ ] HSV-Schwellwerte für Gelb in `detect_lane_node` über Configuration-GUI anpassen
# - [ ] Prüfen ob das Problem nur in bestimmten Lichtverhältnissen auftritt
#
# ### 1.2 Kreuzungsverhalten anpassen (links / geradeaus / rechts)
# - [ ] Kurvenparameter testen: `omega` und `sleep_time` für Links / Geradeaus / Rechts
# - [ ] Werte über Configuration-GUI tunen (`control_lane_node` → Gruppe `intersection`)
# - [ ] Sicherstellen dass Bot nach der Kreuzung wieder sauber in der Spur ist

# %% [markdown]
# ## 2. Duckie Detection testen
#
# - [ ] Notizen aus `Notizen.ipynb` durchgehen
# - [ ] Duckie-Erkennung auf der Strecke testen (Bounding Boxes, Konfidenz)
# - [ ] Ausweichverhalten (`cbAvoidDuckie`) testen und PID-Werte für Duckie-Modus tunen
# - [ ] Prüfen ob Rückkehr in Lane-Modus nach Duckie-Freigabe funktioniert

# %% [markdown]
# 3. Fragen an Leiter:
#     Duckies ausweichen, wie ist es wenn er in eine ente neben sich fährt, ich kann ihm ja nur btutal schwer beibringen wo enten im verhältnis zu ihm waren
#
#     kann die ente auch direkt in der kurve sein
#
#     Bewertungskriterien für die näcshten aufgaben
#
#     Aufgabe 4?
